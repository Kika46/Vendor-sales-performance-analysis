# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import datetime as datetime
import seaborn as sns
import psycopg2
import os
import warnings
warnings.filterwarnings("ignore")

# %%
#Creating dabase connection

"""conn = Main_file.db_connection()
print("Database connected")"""
# Out:
# 'conn = Main_file.db_connection()\nprint("Database connected")'

# %%
conn = psycopg2.connect(
    host="your_host",
    database="your_database",
    user="your_username",
    password="your_password",
    port="your_port")
print("Database connected")
# Out:
# Database connected

# %%
tables =pd.read_sql_query("SELECT table_name FROM information_schema.tables WHERE table_schema='public';" , conn)
print(tables)
# Out:
#         table_name
# 0  begin_inventory
# 1    end_inventory
# 2        purchases
# 3  purchase_prices
# 4            sales
# 5   vendor_invoice

# %%
for table in tables['table_name']:

    df = pd.read_sql_query(f'SELECT COUNT(*) FROM {table};', conn)['count'].values[0]
    print(table,'has',df,'rows')
    display(pd.read_sql_query(f'SELECT * FROM {table} LIMIT 5;', conn))
# Out:
# begin_inventory has 206529 rows
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# end_inventory has 224489 rows
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# ...

# %%
purchases = pd.read_sql_query('SELECT * FROM "purchases" WHERE "VendorNumber"::INT = 4466;', conn)
purchases
# Out:
#                InventoryId  Store  Brand                   Description   Size  \
# 0         30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1        34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2      1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3        38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4      59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                    ...    ...    ...                           ...    ...
# 2187  26_KNIFE'S EDGE_5215     26   5215  TGI Fridays Long Island Iced  1.75L
# 2188       21_BALERNO_3140     21   3140      TGI Fridays Orange Dream  1.75L
# 2189      14_BROMWICH_3140     14   3140      TGI Fridays Orange Dream  1.75L
# 2190       60_IRRAGIN_3140     60   3140      TGI Fridays Orange Dream  1.75L
# 2191      8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases_prices = pd.read_sql_query('SELECT * FROM "purchase_prices" WHERE "VendorNumber"::INT = 4466;', conn)
purchases_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice = pd.read_sql_query('SELECT * FROM "vendor_invoice" WHERE "VendorNumber" = 4466;', conn)
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
sales = pd.read_sql_query('SELECT * FROM "sales" WHERE "VendorNo" = 4466;', conn)
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9449     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases
# Out:
#                InventoryId  Store  Brand                   Description   Size  \
# 0         30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1        34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2      1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3        38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4      59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                    ...    ...    ...                           ...    ...
# 2187  26_KNIFE'S EDGE_5215     26   5215  TGI Fridays Long Island Iced  1.75L
# 2188       21_BALERNO_3140     21   3140      TGI Fridays Orange Dream  1.75L
# 2189      14_BROMWICH_3140     14   3140      TGI Fridays Orange Dream  1.75L
# 2190       60_IRRAGIN_3140     60   3140      TGI Fridays Orange Dream  1.75L
# 2191      8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice['PONumber'].nunique()
# Out:
# 55

# %%
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
purchases
# Out:
#                InventoryId  Store  Brand                   Description   Size  \
# 0         30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1        34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2      1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3        38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4      59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                    ...    ...    ...                           ...    ...
# 2187  26_KNIFE'S EDGE_5215     26   5215  TGI Fridays Long Island Iced  1.75L
# 2188       21_BALERNO_3140     21   3140      TGI Fridays Orange Dream  1.75L
# 2189      14_BROMWICH_3140     14   3140      TGI Fridays Orange Dream  1.75L
# 2190       60_IRRAGIN_3140     60   3140      TGI Fridays Orange Dream  1.75L
# 2191      8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9449     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases.groupby(['Brand', 'PurchasePrice'])[['Quantity', 'Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
result = sales.groupby('Brand')[['SalesDollars','SalesPrice','SalesQuantity']].sum()
print(result)
# Out:
#        SalesDollars  SalesPrice  SalesQuantity
# Brand
# 3140       50531.10    30071.85           3890
# 5215       60416.49    41542.02           4651
# 5255       79187.04    51180.60           6096

# %%
#The purchase  table contains actual purchase data including date of purchase ,product(brands)pruchased by vendors,amount paid in dollar and the quanitty purchased
#purchase price column derived  from the purchase_price columns, which provided product wise actual and purchase prices. Comnbination of Vendor and brnad is unique in thsi table.
#The vendor invoic tabele aggregates data from  the purchase table , summarizing quantity and dollar amount for each purchase order (PO) issued by the vendor. table maintain uniqueness  based on vendor and PO number.
#The sales table records sales transactions, including sales price, quantity sold, and total sales dollars for each brand sold by the vendor. The combination of vendor and brand is unique in this table.

# %%
#As the data that we need  for analysis is distributed  in different tables , we need to create a summary table contianing:
#puchase transactions made by vendors
#sales transactions data
#frieght costs for each vendor
#actual product prices from vendor

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""
SELECT 
    "VendorName","VendorNumber", 
    SUM("Freight" ) AS Total_Freight 
FROM "vendor_invoice" 
GROUP BY "VendorNumber","VendorName"
ORDER BY Total_freight DESC
""", conn)

# %%
freight_summary
# Out:
#                       VendorName  VendorNumber  total_freight
# 0    DIAGEO NORTH AMERICA INC             3960      257032.07
# 1          MARTIGNETTI COMPANIES          4425      144719.92
# 2    JIM BEAM BRANDS COMPANY             12546      123880.97
# 3    PERNOD RICARD USA                   17035      123780.22
# 4    BACARDI USA INC                       480       89286.27
# ..                           ...           ...            ...
# 124  FANTASY FINE WINES CORP             90033           0.61
# 125  AAPER ALCOHOL & CHEMICAL CO            54           0.48
# 126  SILVER MOUNTAIN CIDERS              90026           0.36
# 127  CAPSTONE INTERNATIONAL               1439           0.27
# 128  FLAVOR ESSENCE INC                 201359           0.09
#
# [129 rows x 3 columns]

# %%
purchases_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchases_summary = pd.read_sql_query("""
SELECT 
    p."VendorNumber",
    p."VendorName",
    p."Brand",
    CAST(p."PurchasePrice" AS FLOAT) AS PurchasePrice,
    CAST(pp."Volume" AS FLOAT) AS Volume,
    CAST(pp."Price" AS FLOAT) AS Actual,
    SUM(CAST(p."Quantity" AS FLOAT)) AS TotalQuantity,
    SUM(CAST(p."Dollars" AS FLOAT)) AS TotalPurchaseDollars
FROM "purchase_prices" AS pp
JOIN "purchases" AS p
    ON pp."Brand" = p."Brand"
WHERE CAST(p."PurchasePrice" AS FLOAT) > 0
GROUP BY 
    p."VendorNumber",
    p."VendorName",
    p."Brand",
    p."PurchasePrice",
    pp."Volume",
    pp."Price"
ORDER BY TotalPurchaseDollars;
""", conn)

purchases_summary
# Out:
#        VendorNumber                   VendorName  Brand  purchaseprice  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74
# 3              8004  SAZERAC CO INC                5683           0.39
# 4              9815  WINE GROUP INC                8527           1.32
# ...             ...                          ...    ...            ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17
# 10689         17035  PERNOD RICARD USA             8068          18.24
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19
# 10691          1128  BROWN-FORMAN CORP             1233          26.27
#
#        volume  actual  totalquantity  totalpurchasedollars
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""
SELECT 
    "VendorNo",
    "Brand",
    SUM("SalesPrice") AS TotalSalesPrice,
    SUM("SalesQuantity") AS TotalSalesQuantity,
    SUM("SalesDollars" ) AS TotalSalesDollars,
    SUM("ExciseTax" ) AS TotalExciseTax
FROM "sales"
GROUP BY "VendorNo", "Brand"
ORDER BY TotalSalesDollars;""",conn)
# Out:
#        VendorNo  Brand  totalsalesprice  totalsalesquantity  \
# 0          8004   5287             0.98                 2.0
# 1          9206   2773             0.99                 1.0
# 2          3924   9123             0.99                 2.0
# 3          3252   3933             0.99                 2.0
# 4         10050   3623             1.98                 2.0
# ...         ...    ...              ...                 ...
# 11267      3960   3545        545778.28            135838.0
# 11268      3960   4261        420050.01            200412.0
# 11269     17035   8068        461140.15            187140.0
# 11270      4425   3405        561512.37            160247.0
# 11271      1128   1233        672819.31            142049.0
#
#        totalsalesdollars  totalexcisetax
# 0                   0.98            0.10
# 1                   0.99            0.05
# 2                   1.98            0.10
# 3                   1.98            0.10
# ...

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
purchases_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %% [markdown]
# import time
# start_time = time.time()
#
# #final_table = pd.read_sql_query("""
# """SELECT
#     pp."VendorNumber",
#     pp."VendorName",
#     pp."Brand",
#     pp."PurchasePrice",
#     SUM(s."SalesPrice") AS TotalSalesPrice,
#     SUM(s."SalesQuantity") AS TotalSalesQuantity,
#     SUM(s."SalesDollars") AS TotalSalesDollars,
#     SUM(s."ExciseTax") AS TotalExciseTax,
#     SUM(vi."Freight") AS Total_Freight,
#     SUM(vi."Quantity") AS TotalQuantity,
#     SUM(vi."Dollars") AS TotalPurchaseDollars
# FROM "purchase_prices" AS pp
# JOIN "sales" AS s
#     ON pp."Brand" = s."Brand" AND pp."VendorNumber" = s."VendorNo"
# JOIN "vendor_invoice" AS vi
#     ON s."VendorNo" = vi."VendorNumber"
# GROUP BY
#     pp."VendorNumber",
#     pp."VendorName",
#     pp."Brand",
#     pp."PurchasePrice"
# ORDER BY TotalSalesDollars DESC;
# """, "conn)
# end_time = time.time()
# print(f" executed in {end_time - start_time:.2f} seconds")

# %%
freight_summary
# Out:
#                       VendorName  VendorNumber  total_freight
# 0    DIAGEO NORTH AMERICA INC             3960      257032.07
# 1          MARTIGNETTI COMPANIES          4425      144719.92
# 2    JIM BEAM BRANDS COMPANY             12546      123880.97
# 3    PERNOD RICARD USA                   17035      123780.22
# 4    BACARDI USA INC                       480       89286.27
# ..                           ...           ...            ...
# 124  FANTASY FINE WINES CORP             90033           0.61
# 125  AAPER ALCOHOL & CHEMICAL CO            54           0.48
# 126  SILVER MOUNTAIN CIDERS              90026           0.36
# 127  CAPSTONE INTERNATIONAL               1439           0.27
# 128  FLAVOR ESSENCE INC                 201359           0.09
#
# [129 rows x 3 columns]

# %%
vendor_sales_summary = pd.read_sql_query("""
WITH FreightSummary AS (
    SELECT
        "VendorNumber", 
        SUM("Freight") AS Total_Freight
    FROM "vendor_invoice"
    GROUP BY "VendorNumber"
), 

PurchaseSummary AS (
    SELECT 
        p."VendorNumber",
        p."VendorName",
        p."Brand",
        p."Description",
        p."PurchasePrice",
        pp."Volume",
        pp."Price" AS "actualPrice",
        SUM(p."Quantity") AS TotalQuantity,
        SUM(p."Dollars") AS TotalPurchaseDollars
    FROM "purchase_prices" AS pp
    JOIN "purchases" AS p
        ON pp."Brand" = p."Brand"
    WHERE p."PurchasePrice" > 0
    GROUP BY 
        p."VendorNumber",
        p."VendorName",
        p."Brand",
        p."Description",
        p."PurchasePrice",
        pp."Volume",
        pp."Price"
),

SalesSummary AS (
    SELECT 
        "VendorNo",
        "Brand",
        SUM("SalesPrice") AS TotalSalesPrice,
        SUM("SalesQuantity") AS TotalSalesQuantity,
        SUM("SalesDollars") AS TotalSalesDollars,
        SUM("ExciseTax") AS TotalExciseTax
    FROM "sales"
    GROUP BY "VendorNo", "Brand"
)

SELECT
    ps."VendorNumber",
    ps."VendorName",
    ps."Brand",
    ps."Description",
    ps."PurchasePrice",
    ps."Volume",
    ps."actualPrice",
    ps.TotalQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesPrice,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalExciseTax,
    fs.Total_Freight
FROM PurchaseSummary AS ps
LEFT JOIN SalesSummary AS ss
    ON ps."VendorNumber" = ss."VendorNo" AND ps."Brand" = ss."Brand"
LEFT JOIN FreightSummary AS fs
    ON ps."VendorNumber" = fs."VendorNumber"
ORDER BY ss.TotalSalesDollars;
""", conn)

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              3924  HEAVEN HILL DISTILLERIES      9123
# 1              4425        MARTIGNETTI COMPANIES  27934
# 2              8673  STE MICHELLE WINE ESTATES    13344
# 3              5612  MILTONS DISTRIBUTING CO      17675
# 4              9815  WINE GROUP INC               26950
# ...             ...                          ...    ...
# 10687          6785  PALM BAY INTERNATIONAL INC   21781
# 10688          4425        MARTIGNETTI COMPANIES  24955
# 10689          9165  ULTRA BEVERAGE COMPANY LLP   24981
# 10690          1650  Circa Wines                   5016
# 10691          7153  PINE STATE TRADING CO        22103
#
#                         Description  PurchasePrice Volume  actualPrice  \
# 0                   Deep Eddy Vodka           0.74     50         0.99
# 1       Terruzzi & Puthod Vernaccia           3.37    750         4.99
# 2      Columbia Crest Two Vines Rsl           3.57   1500         5.29
# ...

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber              int64
# VendorName               object
# Brand                     int64
# Description              object
# PurchasePrice           float64
# Volume                   object
# actualPrice             float64
# totalquantity           float64
# totalpurchasedollars    float64
# totalsalesprice         float64
# totalsalesquantity      float64
# totalsalesdollars       float64
# totalexcisetax          float64
# total_freight           float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber              0
# VendorName                0
# Brand                     0
# Description               0
# PurchasePrice             0
# Volume                    0
# actualPrice               0
# totalquantity             0
# totalpurchasedollars      0
# totalsalesprice         178
# totalsalesquantity      178
# totalsalesdollars       178
# totalexcisetax          178
# total_freight             0
# dtype: int64

# %%
vendor_sales_summary.fillna(0,inplace=True)

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber            0
# VendorName              0
# Brand                   0
# Description             0
# PurchasePrice           0
# Volume                  0
# actualPrice             0
# totalquantity           0
# totalpurchasedollars    0
# totalsalesprice         0
# totalsalesquantity      0
# totalsalesdollars       0
# totalexcisetax          0
# total_freight           0
# dtype: int64

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber              int64
# VendorName               object
# Brand                     int64
# Description              object
# PurchasePrice           float64
# Volume                   object
# actualPrice             float64
# totalquantity           float64
# totalpurchasedollars    float64
# totalsalesprice         float64
# totalsalesquantity      float64
# totalsalesdollars       float64
# totalexcisetax          float64
# total_freight           float64
# dtype: object

# %%
vendor_sales_summary['Volume'] = vendor_sales_summary['Volume'].astype(float)

# %%
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'].str.strip()

# %%
vendor_sales_summary['Description'].unique()
# Out:
# array(['Deep Eddy Vodka', 'Terruzzi & Puthod Vernaccia',
#        'Columbia Crest Two Vines Rsl', ...,
#        'Opici Homemade Barberone Red', 'Villa Zarri Coffee Brandy',
#        'Nodus Cava Brut'], shape=(9651,), dtype=object)

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber              int64
# VendorName               object
# Brand                     int64
# Description              object
# PurchasePrice           float64
# Volume                  float64
# actualPrice             float64
# totalquantity           float64
# totalpurchasedollars    float64
# totalsalesprice         float64
# totalsalesquantity      float64
# totalsalesdollars       float64
# totalexcisetax          float64
# total_freight           float64
# dtype: object

# %%
vendor_sales_summary['Gross_Profit'] = vendor_sales_summary['totalsalesdollars'] - vendor_sales_summary['totalpurchasedollars']

# %%
vendor_sales_summary['Profimargin'] = (vendor_sales_summary['Gross_Profit'] / vendor_sales_summary['totalsalesdollars']) * 100

# %%
vendor_sales_summary
# Out:
#        VendorNumber                 VendorName  Brand  \
# 0              3924   HEAVEN HILL DISTILLERIES   9123
# 1              4425      MARTIGNETTI COMPANIES  27934
# 2              8673  STE MICHELLE WINE ESTATES  13344
# 3              5612    MILTONS DISTRIBUTING CO  17675
# 4              9815             WINE GROUP INC  26950
# ...             ...                        ...    ...
# 10687          6785             M S WALKER INC  21781
# 10688          4425      PINE STATE TRADING CO  24955
# 10689          9165      MARTIGNETTI COMPANIES  24981
# 10690          1650      PINE STATE TRADING CO   5016
# 10691          7153             M S WALKER INC  22103
#
#                         Description  PurchasePrice  Volume  actualPrice  \
# 0                   Deep Eddy Vodka           0.74    50.0         0.99
# 1       Terruzzi & Puthod Vernaccia           3.37   750.0         4.99
# 2      Columbia Crest Two Vines Rsl           3.57  1500.0         5.29
# ...

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'Volume', 'actualPrice', 'totalquantity', 'totalpurchasedollars',
#        'totalsalesprice', 'totalsalesquantity', 'totalsalesdollars',
#        'totalexcisetax', 'total_freight', 'Gross_Profit', 'Profimargin'],
#       dtype='object')

# %%
vendor_sales_summary['StockTurover']= (vendor_sales_summary['totalsalesquantity'] / vendor_sales_summary['totalquantity'] )

# %%
vendor_sales_summary
# Out:
#        VendorNumber                 VendorName  Brand  \
# 0              3924   HEAVEN HILL DISTILLERIES   9123
# 1              4425      MARTIGNETTI COMPANIES  27934
# 2              8673  STE MICHELLE WINE ESTATES  13344
# 3              5612    MILTONS DISTRIBUTING CO  17675
# 4              9815             WINE GROUP INC  26950
# ...             ...                        ...    ...
# 10687          9552             M S WALKER INC  27708
# 10688          7153      PINE STATE TRADING CO  14647
# 10689          4425      MARTIGNETTI COMPANIES  24525
# 10690          7153      PINE STATE TRADING CO  21127
# 10691          9552             M S WALKER INC   2221
#
#                         Description  PurchasePrice  Volume  actualPrice  \
# 0                   Deep Eddy Vodka           0.74    50.0         0.99
# 1       Terruzzi & Puthod Vernaccia           3.37   750.0         4.99
# 2      Columbia Crest Two Vines Rsl           3.57  1500.0         5.29
# ...

# %%
vendor_sales_summary['Sales_to_Purchase_Ratio'] = vendor_sales_summary['totalsalesdollars'] / vendor_sales_summary['totalpurchasedollars']

# %%
vendor_sales_summary
# Out:
#        VendorNumber                 VendorName  Brand  \
# 0              3924   HEAVEN HILL DISTILLERIES   9123
# 1              4425      MARTIGNETTI COMPANIES  27934
# 2              8673  STE MICHELLE WINE ESTATES  13344
# 3              5612    MILTONS DISTRIBUTING CO  17675
# 4              9815             WINE GROUP INC  26950
# ...             ...                        ...    ...
# 10687          6785             M S WALKER INC  21781
# 10688          4425      PINE STATE TRADING CO  24955
# 10689          9165      MARTIGNETTI COMPANIES  24981
# 10690          1650      PINE STATE TRADING CO   5016
# 10691          7153             M S WALKER INC  22103
#
#                         Description  PurchasePrice  Volume  actualPrice  \
# 0                   Deep Eddy Vodka           0.74    50.0         0.99
# 1       Terruzzi & Puthod Vernaccia           3.37   750.0         4.99
# 2      Columbia Crest Two Vines Rsl           3.57  1500.0         5.29
# ...

# %%
cur = conn.cursor()

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber                 int64
# VendorName                  object
# Brand                        int64
# Description                 object
# PurchasePrice              float64
# Volume                     float64
# actualPrice                float64
# totalquantity              float64
# totalpurchasedollars       float64
# totalsalesprice            float64
# totalsalesquantity         float64
# totalsalesdollars          float64
# totalexcisetax             float64
# total_freight              float64
# Gross_Profit               float64
# Profimargin                float64
# StockTurover               float64
# Sales_to_Purchase_Ratio    float64
# dtype: object

# %%
vendor_sales_summary['VendorName'].dtype
# Out:
# dtype('O')

# %%
tables = pd.read_sql_query("""
SELECT tablename 
FROM pg_catalog.pg_tables 
WHERE schemaname = 'public';
""", conn)

print(tables)
# Out:
#          tablename
# 0  begin_inventory
# 1    end_inventory
# 2        purchases
# 3  purchase_prices
# 4            sales
# 5   vendor_invoice

# %%
conn.rollback()

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'Volume', 'actualPrice', 'totalquantity', 'totalpurchasedollars',
#        'totalsalesprice', 'totalsalesquantity', 'totalsalesdollars',
#        'totalexcisetax', 'total_freight', 'Gross_Profit', 'Profimargin',
#        'StockTurover', 'Sales_to_Purchase_Ratio'],
#       dtype='object')

# %%
cur = conn.cursor()

cur.execute("DROP TABLE IF EXISTS vendor_sales_summary;")


cur.execute("""
    CREATE TABLE vendor_sales_summary (
        vendornumber INT,
        vendorname VARCHAR(100),
        brand INT,
        description VARCHAR(100),
        purchaseprice DECIMAL(10,2),
        actualprice DECIMAL(10,2),
        volume INT,
        totalquantity INT,
        totalpurchasedollars DECIMAL(15,2),
        totalsalesquantity INT,
        totalsalesdollars DECIMAL(15,2),
        totalsalesprice DECIMAL(15,2),
        totalexcisetax DECIMAL(15,2),
        total_freight DECIMAL(15,2),
        grossprofit DECIMAL(15,2),
        profitmargin DECIMAL(15,2),
        stockturnover DECIMAL(15,2),
        salestopurchaseratio DECIMAL(15,2),
        PRIMARY KEY (vendornumber, brand)
    );
""")


conn.commit()
print("Database table 'vendor_sales_summary' has been reset and recreated.")
# Out:
# Database table 'vendor_sales_summary' has been reset and recreated.

# %%
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:Kisan@localhost:5432/Vendors_db')


vendor_sales_summary.to_sql('vendor_sales_summary',engine,if_exists='replace',index=False)
print("✅ Success! All data loaded into 'vendor_sales_summary'.")
# Out:
# ✅ Success! All data loaded into 'vendor_sales_summary'.
